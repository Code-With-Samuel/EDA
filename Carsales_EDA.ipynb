# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
read_df = pd.read_csv('/content/drive/MyDrive/aiml_class/Car_sales.csv')
read_df
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
# ...

# %%
read_df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
read_df.isnull()
# Out:
#      Manufacturer  Model  Sales in thousands  4-year resale value  \
# 0           False  False               False                False
# 1           False  False               False                False
# 2           False  False               False                False
# 3           False  False               False                False
# 4           False  False               False                False
# ..            ...    ...                 ...                  ...
# 152         False  False               False                False
# 153         False  False               False                False
# 154         False  False               False                False
# 155         False  False               False                False
# 156         False  False               False                False
#
#      Vehicle type  Price in thousands  Engine size  Horsepower  Wheelbase  \
# 0           False               False        False       False      False
# ...

# %%
read_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# ...

# %%
read_df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# ...

# %%
read_df.tail()
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
# ...

# %%
read_df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
read_df['Manufacturer'] = read_df['Manufacturer'].str.strip()
read_df.loc[read_df.Manufacturer == 'Dodge']
# Out:
#    Manufacturer              Model  Sales in thousands 4-year resale value  \
# 35        Dodge  Neon                           76.034                7.75
# 36        Dodge  Avenger                         4.734              12.545
# 37        Dodge  Stratus                        71.186              10.185
# 38        Dodge  Intrepid                       88.028              12.275
# 39        Dodge  Viper                           0.916               58.47
# 40        Dodge  Ram Pickup                    227.061               15.06
# 41        Dodge  Ram Wagon                      16.767               15.51
# 42        Dodge  Ram Van                        31.038              13.425
# 43        Dodge  Dakota                        111.313               11.26
# 44        Dodge  Durango                       101.323                   .
# 45        Dodge  Caravan                       181.749              12.025
#
# ...

# %%
read_df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Ford             11
# Dodge            11
# Chevrolet         9
# Mercedes-Benz     9
# Toyota            9
# Chrysler          7
# Mitsubishi        7
# Nissan            7
# Mercury           6
# Oldsmobile        6
# Lexus             6
# Pontiac           6
# Volvo             6
# Volkswagen        6
# Cadillac          5
# Honda             5
# Saturn            5
# Plymouth          4
# Buick             4
# Acura             4
# Audi              3
# BMW               3
# Lincoln           3
# Porsche           3
# Jeep              3
# Hyundai           3
# Saab              2
# Subaru            2
# Jaguar            1
# Infiniti          1
# Name: count, dtype: int64

# %%
plt.figure(figsize = (12,6))
sns.countplot(y="Manufacturer",order = read_df['Manufacturer'].value_counts().index[0:10],data = read_df)
plt.show()

# %%
# read_df.plot(x='Manufacturer', y="Sales in thousands", kind = "bar", title= 'Bar graph')
# plt.show()

# %%
read_df.groupby('Manufacturer').sum()
# Out:
#                                                            Model  \
# Manufacturer
# Acura          Integra          TL               CL          ...
# Audi           A4               A6               A8          ...
# BMW            323i             328i             528i        ...
# Buick          Century          Regal            Park Avenue ...
# Cadillac       DeVille          Seville          Eldorado    ...
# Chevrolet      Cavalier         Malibu           Lumina      ...
# Chrysler       Sebring Coupe    Sebring Conv.    Concorde    ...
# Dodge          Neon             Avenger          Stratus     ...
# Ford           Escort           Mustang          Contour     ...
# Honda          Civic            Accord           CR-V        ...
# Hyundai        Accent           Elantra          Sonata      ...
# Infiniti                                       I30
# Jaguar                                         S-Type
# Jeep           Wrangler         Cherokee         Grand Cherok...
# ...

# %%
read_df_2 = read_df.groupby('Manufacturer')['Sales in thousands'].sum()
read_df_2
# Out:
# Manufacturer
# Acura              79.005
# Audi               40.557
# BMW                46.505
# Buick             242.019
# Cadillac          112.178
# Chevrolet         554.365
# Chrysler          201.721
# Dodge             910.149
# Ford             2022.635
# Honda             592.674
# Hyundai           137.326
# Infiniti           23.713
# Jaguar             15.467
# Jeep              293.153
# Lexus             106.843
# Lincoln            85.634
# Mercedes-Benz     117.125
# Mercury           237.999
# Mitsubishi        180.895
# Nissan            399.635
# Oldsmobile        178.989
# Plymouth           64.001
# Pontiac           370.534
# Porsche            12.128
# Saab               21.306
# Saturn            168.850
# Subaru             80.135
# Toyota            740.205
# Volkswagen        209.212
# Volvo              75.740
# Name: Sales in thousands, dtype: float64

# %%
read_df_2.plot(x ="Manufacturer", y ="Sales in thousands", kind = "pie")
read_df_2
# Out:
# Manufacturer
# Acura              79.005
# Audi               40.557
# BMW                46.505
# Buick             242.019
# Cadillac          112.178
# Chevrolet         554.365
# Chrysler          201.721
# Dodge             910.149
# Ford             2022.635
# Honda             592.674
# Hyundai           137.326
# Infiniti           23.713
# Jaguar             15.467
# Jeep              293.153
# Lexus             106.843
# Lincoln            85.634
# Mercedes-Benz     117.125
# Mercury           237.999
# Mitsubishi        180.895
# Nissan            399.635
# Oldsmobile        178.989
# Plymouth           64.001
# Pontiac           370.534
# Porsche            12.128
# Saab               21.306
# Saturn            168.850
# Subaru             80.135
# Toyota            740.205
# Volkswagen        209.212
# Volvo              75.740
# Name: Sales in thousands, dtype: float64

# %%
sns.scatterplot(data = read_df, y ="Fuel efficiency" ,x = "Sales in thousands")
plt.title("Scatter Plot")
plt.legend()
plt.show()
# Out:
# <ipython-input-20-bca9e715dff8>:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
